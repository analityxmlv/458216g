# %% [markdown]
# ![bees](bees.jpg)

# %% [markdown]
# # ¿Que plantas son mejores para las abejas: nativas o no nativas?
#
# ## 📖 Background
# Usted trabaja para la agencia ambiental del gobierno local y ha emprendido un proyecto sobre la creación de espacios amigables para las abejas polinizadoras. Puede usar plantas nativas y no nativas para crear estos espacios y, por lo tanto, debe asegurarse de usar las plantas correctas para optimizar el entorno para estas abejas.
#
# El equipo ha recopilado datos sobre plantas nativas y no nativas y sus efectos en las abejas polinizadoras. Su tarea será analizar estos datos y proporcionar recomendaciones sobre qué plantas crean un entorno optimizado para las abejas polinizadoras.

# %% [markdown]
# ## Los datos
# Se ha reunido información sobre la investigación de plantas y abejas en un archivo llamado `plants_and_bees.csv`. Cada fila representa una muestra que se tomó de un terreno donde se estaban estudiando las especies de plantas.
#
# | Columna     | Descripción              |
# |------------|--------------------------|
# | `sample_id` | El número de ID de la muestra tomada. |
# | `species_num` | El número de diferentes especies de abejas en la muestra. |
# | `date` | Fecha en que se tomó la muestra. |
# | `season` | Temporada durante la recogida de muestras ("early.season" or "late.season"). |
# | `site` | Nombre del sitio de recolección. |
# | `native_or_non` | Si la muestra era de una planta nativa o no nativa. |
# | `sampling` | El método de muestreo. |
# | `plant_species` | El nombre de la especie vegetal de la que se tomó la muestra. None indica que la muestra se tomó del aire. |
# | `time` | La hora en que se tomó la muestra. |
# | `bee_species` | La especie de abeja en la muestra. |
# | `sex` | El género de la especie de abeja. |
# | `specialized_on` | El género de la especie de abeja. |
# | `parasitic` | Si la abeja es parásita o no (0:no, 1:yes). |
# | `nesting` | El método de anidación de las abejas. |
# | `status` | El estado de las especies de abejas. |
# | `nonnative_bee` | Si la especie de abeja es nativa o no (0:no, 1:yes). |
#
# [Source](https://datadryad.org/stash/dataset/doi%253A10.5061%252Fdryad.pzgmsbcj8) (estos datos han sido modificados)

# %% [markdown]
# Proporcione a su agencia un informe que cubra lo siguiente:
#
# * ¿Qué plantas son preferidas por las especies de abejas nativas frente a las no nativas?
# * Una visualización de la distribución de especies de abejas y plantas en una de las muestras.
# * Seleccione las tres principales especies de plantas que recomendaría a la agencia para apoyar a las abejas nativas.

# %%
import pandas as pd
data = pd.read_csv("data/plants_and_bees.csv")
data
# Out:
#       sample_id  species_num        date  ... nesting status nonnative_bee
# 0         17400           23  04/18/2017  ...  ground    NaN           0.0
# 1         17400           23  04/18/2017  ...  ground    NaN           0.0
# 2         17400           23  04/18/2017  ...  ground    NaN           0.0
# 3         17400           23  04/18/2017  ...  ground    NaN           0.0
# 4         17400           23  04/18/2017  ...  ground    NaN           0.0
# ...         ...          ...         ...  ...     ...    ...           ...
# 1245      17481           11  08/02/2017  ...  ground    NaN           0.0
# 1246      17481           11  08/02/2017  ...  ground    NaN           0.0
# 1247      17481           11  08/02/2017  ...  ground    NaN           0.0
# 1248      17481           11  08/02/2017  ...  ground    NaN           0.0
# 1249      17481           11  08/02/2017  ...  ground    NaN           0.0
#
# [1250 rows x 16 columns]
